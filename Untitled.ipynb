# %%
from Environment.rrt import RRT
import numpy as np
from matplotlib import pyplot as plt

# %%
obstacleList = [(5, 5, 1), (3, 6, 2), (3, 8, 2), (3, 10, 2), (7, 5, 2),
                    (9, 5, 2), (8, 10, 1)]  # [x, y, radius]
# Set Initial parameters
rrt = RRT(
    start=[0, 0],
    goal=[10, 10],
    rand_area=[-2, 15],
    obstacle_list=obstacleList, expand_dis= 1
    # play_area=[0, 10, 0, 14]
    )
path = rrt.planning(animation=True)

if path is None:
    print("Cannot find path")
else:
    print("found path!!")

    # Draw final path
    
rrt.draw_graph()
plt.plot([x for (x, y) in path], [y for (x, y) in path], '-r')
plt.grid(True)
plt.pause(0.01)  # Need for Mac
plt.show()
# Out:
# found path!!

# %%
path = np.array(path)

# %%
np.squeeze(np.array([[1234]]),axis=-1)
# Out:
# array([1234])

# %%
all_atoms = np.array([[1,2], [1,3], [2,4]])
a = np.array([1,3])

# %%
a.tolist() in all_atoms.tolist()
# Out:
# True

# %%
a = np.array([[22,36], [43,36], [33,54], [64,36], [85,36], [75,54], [106,36],[127,36]])
plt.plot(a[:,0], a[:,1])

# %%
22 36
43 36
33 54
64 36
85 36
75 54
106 36
127 36
117 54
148 36
169 36
159 54
190 36
211 36
201 54
232 36
22 36
43 36
33 54
44 72
65 72
55 90
86 72
107 72
97 90
128 72
149 72
139 90
170 72
191 72
181 90
212 72
233 72
223 90
23 72
44 72
65 72
55 90
66 108
87 108
77 126
108 108
129 108
119 126
150 108
171 108
161 126
192 108
213 108
203 126
234 108
24 108
45 108
35 126
66 108
87 108
77 126
88 144
109 144
99 162
130 144
151 144
141 162
172 144
193 144
183 162
214 144
235 144
225 162
25 144
46 144
67 144
57 162
88 144
109 144
99 162
110 180
131 180
121 198
152 180
173 180
163 198
194 180
215 180
205 198
26 180
47 180
37 198
68 180
89 180
79 198
110 180
131 180
121 198
132 216
153 216
143 234
174 216
195 216
185 234
216 216
227 234
27 216
48 216
69 216
59 234
90 216
111 216
101 234
132 216
153 216
143 234

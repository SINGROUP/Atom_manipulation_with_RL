# %%
from matplotlib import pyplot as plt
plt.plot([1,2,3])
import numpy as np
import scipy
import scipy.spatial as spatial
import copy
from Environment.Builder_Env import Structure_Builder, circle, assignment
from RL.sac import sac_agent
import matplotlib
import torch
from Environment.data_visualization import show_reset, show_done, show_step, plot_large_frame
from Environment.episode_memory import Episode_Memory
from Environment.createc_control import Createc_Controller

matplotlib.rcParams['image.cmap'] = 'gray'
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda:0

# %%
import importlib
import Environment.Builder_Env
importlib.reload(Environment.Builder_Env)
from Environment.Builder_Env import Structure_Builder

# %%
def RL_operation(env, agent, atom_chosen, next_destination_nm, anchor_chosen, offset_nm, len_nm, i_episode, max_steps=5):
    done = False
    state, info = env.reset(next_destination_nm, anchor_chosen, offset_nm, len_nm, large_len_nm)
        
    show_reset(env.img_info, env.atom_start_absolute_nm, env.destination_absolute_nm)
    episode_memory.update_memory_reset(env.img_info, i_episode, info)
    
    for step in range(max_steps):
        print('step:', step)
        if np.linalg.norm(env.atom_absolute_nm - atom_chosen)>2:
            print('identify the wrong atom')
            break
            
        action = agent.select_action(state)
        next_state, reward, done, info = env.step(action)
        mask = float(not done)
        episode_memory.update_memory_step(state, action, next_state, reward, done, info)
        state=next_state
        print('precision:', env.dist_destination, 'nm')
        show_step(env.img_info, info['start_nm']+env.atom_absolute_nm, info['end_nm']+env.atom_absolute_nm,env.atom_absolute_nm, 
                  env.atom_start_absolute_nm, env.destination_absolute_nm, 
                  action[4]*env.max_mvolt, action[5]*env.max_pcurrent_to_mvolt_ratio*action[4]*env.max_mvolt)
        if done:
            episode_memory.update_memory_done(env.img_info, env.atom_absolute_nm, np.array([0,0]))
            episode_memory.save_memory(folder_name)
            break
    return env.atom_absolute_nm, env.dist_destination

# %%
batch_size= 64
LEARNING_RATE = 0.0003
agent = sac_agent(num_inputs = 4, num_actions = 6, action_space = None, device=device, hidden_size=256, lr=LEARNING_RATE,
                 gamma=0.9, tau=0.005, alpha=1)
weight_folder_name = 'C:/LocalUserData/User-data/phys-asp-lab/auto_manipulation/training_Ag'
episode = 600
agent.critic.load_state_dict(torch.load('{}/_critic_{}.pth'.format(weight_folder_name, episode)))
agent.policy.load_state_dict(torch.load('{}/_policy_{}.pth'.format(weight_folder_name, episode)))
agent.alpha = torch.load('{}/_alpha_{}.pth'.format(weight_folder_name, episode))
episode_memory = Episode_Memory()

# %%
design_nm = np.array([[ 0. ,  0. ],[ 1.1,  1.8],
                   [ 2.2,  3.6],[ 3.2,  1.8],
                   [ 4.2,  0. ],[ 3.1, -1.8],
                   [ 2. , -3.6],[ 1. , -1.8]])
plt.subplots(figsize=(5,5))
plt.scatter(design_nm[:,0], design_nm[:,1])

# %%
#test offset extration
createc_controller = Createc_Controller(None, None, None, None)
DAC_unit = 2**19
volt_unit = 10
Xgain = float(createc_controller.stm.getparam("GainX"))
Ygain = float(createc_controller.stm.getparam("GainY"))
Xpiezoconst = float(createc_controller.stm.getparam("Xpiezoconst"))
Ypiezoconst = float(createc_controller.stm.getparam("Ypiezoconst"))
x_nm = -0.1*Xpiezoconst*volt_unit*float(createc_controller.stm.getparam('OffsetX'))*Xgain/DAC_unit
y_nm = -0.1*Ypiezoconst*volt_unit*float(createc_controller.stm.getparam('OffsetY'))*Ygain/DAC_unit
print(x_nm, y_nm)

step_nm = 0.4
max_mvolt = 15 #min_mvolt = 0.5*max_mvolt
max_pcurrent_to_mvolt_ratio = 6E3 # min = 0.5*max
goal_nm  = 2
current_jump  = 4
large_len_nm = 12.015
large_offset_nm = np.array([x_nm, y_nm])
pixel = 128
scan_mV = 100
max_len = 5
speed = 1500
folder_name = 'C:/LocalUserData/User-data/phys-asp-lab/auto_manipulation/diamond_build'

env = Structure_Builder(step_nm, max_mvolt, max_pcurrent_to_mvolt_ratio, goal_nm, 
                 current_jump, large_len_nm, large_offset_nm, pixel, scan_mV, max_len, 
                        speed = speed, precision_lim = 0.288, safe_radius_nm = 0.8)
# Out:
# succeed to connect
# 56.341217041015625 -204.49478149414062
# succeed to connect
# speed: 1500

# %%
num_steps = 10

#atom_chosen, design_chosen, next_destination_nm, path, anchor_chosen, offset_nm, len_nm = env.reset_large(design_nm, 
                                                                                                          #align_design_mode = 'auto')
#np.save(folder_name+'/{}_episode_img_info.npy'.format(-1),env.large_img_info)
for i in range(15, 20):
    print('STEP:', i)
    plot_large_frame(env.large_img_info, atom_chosen, design_chosen, anchor_chosen, next_destination_nm, path)
    new_atom_position, dist_destination = RL_operation(env, agent, atom_chosen, next_destination_nm, anchor_chosen, offset_nm, len_nm, i)
    succeed = dist_destination<env.precision_lim
    atom_chosen, design_chosen, next_destination_nm, path, anchor_chosen, offset_nm, len_nm, done = env.step_large(succeed, new_atom_position)
    if succeed:
        print('design:',env.design_chosen,'destination:',env.next_destinatio_nm)
        print('Episode success, designs remain:', env.designs.shape[0], 'atoms remain:',env.atoms.shape[0])
    np.save(folder_name+'/{}_episode_img_info.npy'.format(i), env.large_img_info)
    if done:
        break
# Out:
# STEP: 15
# The scan will take 20.3 seconds
# anchor from small scan: [  55.95921567 -200.63171204] anchor from large scan: [  55.96935182 -200.69299939]
# step: 0
# 57 63 75 81
# Old prediction: False
# Prediction: 0.5233067
# cnn thinks there is atom movement
# The scan will take 9.8 seconds
# atom moves by: 0.8065095220137988
# precision: 0.3634079791880133 nm
# step: 1
# 80 87 61 80
# Old prediction: True
# Prediction: 0.50821185
# cnn thinks there is atom movement
# The scan will take 9.8 seconds
# atom moves by: 0.6514421693796618
# precision: 0.38390640570810197 nm
# step: 2
# 73 82 73 88
# Old prediction: False
# Prediction: 0.50513244
# cnn thinks there is atom movement
# The scan will take 9.8 seconds
# atom moves by: 0.7024080746554566
# precision: 0.2850261409933243 nm
# The scan will take 9.8 seconds
# update after success
# atoms before: [[  53.60979094 -200.72484944]
#  [  55.0824425  -199.10095   ]
#  [  57.21181132 -198.54169827]]
# (array([2], dtype=int64),)
# atoms after: [[  53.60979094 -200.72484944]
#  [  55.0824425  -199.10095   ]]
# designs before: [[  53.9813894 -200.6906658]
#  [  54.9813894 -202.4906658]
#  [  57.1813894 -198.8906658]]
# designs after: [[  53.9813894 -200.6906658]
#  [  54.9813894 -202.4906658]]
# start: [  55.0824425 -199.10095  ] goal [  54.9813894 -202.4906658]
# Cannot find path
# start: [  53.60979094 -200.72484944] goal [  53.9813894 -200.6906658]
# design: [  53.9813894 -200.6906658] destination: [  53.9813894 -200.6906658]
# Episode success, designs remain: 2 atoms remain: 2
# STEP: 16
# The scan will take 20.3 seconds
# anchor from small scan: [  53.11917403 -199.12968888] anchor from large scan: [  53.02038117 -199.11377306]
# step: 0
# 65 72 76 67
# Old prediction: False
# Prediction: 0.51023
# cnn thinks there is atom movement
# The scan will take 9.8 seconds
# atom moves by: 0.3345587577815237
# precision: 0.12004973126755149 nm
# The scan will take 9.8 seconds
# update after success
# atoms before: [[  55.09958968 -195.43569437]
#  [  55.10642649 -202.6950046 ]]
# (array([], dtype=int64),)
# atoms after: [[  55.09958968 -195.43569437]
#  [  55.10642649 -202.6950046 ]]
# designs before: [[  53.9813894 -200.6906658]
#  [  54.9813894 -202.4906658]]
# designs after: [[  54.9813894 -202.4906658]]
# start: [  55.10642649 -202.6950046 ] goal [  54.9813894 -202.4906658]
# design: [  54.9813894 -202.4906658] destination: [  54.9813894 -202.4906658]
# Episode success, designs remain: 1 atoms remain: 2
# STEP: 17
# The scan will take 20.3 seconds
# anchor from small scan: [  56.00757261 -200.63744164] anchor from large scan: [  55.95891113 -200.62495403]
# step: 0
# 59 66 58 59
# Old prediction: False
# Prediction: 0.5053235
# cnn thinks there is atom movement
# The scan will take 9.8 seconds
# atom moves by: 0.435343751433464
# precision: 0.551546851622245 nm
# step: 1
# 57 62 65 71
# Old prediction: False
# Prediction: 0.5052726
# cnn thinks there is atom movement
# The scan will take 9.8 seconds
# atom moves by: 0.403502115304327
# precision: 0.5031254339017678 nm
# step: 2
# 54 61 65 75
# Old prediction: True
# Prediction: 0.513393
# cnn thinks there is atom movement
# The scan will take 9.8 seconds
# atom moves by: 0.26875475381863484
# precision: 0.059975271503065974 nm
# The scan will take 9.8 seconds
# update after success
# atoms before: [[  55.09503801 -195.41826325]]
# (array([], dtype=int64),)
# atoms after: [[  55.09503801 -195.41826325]]
# designs before: [[  54.9813894 -202.4906658]]
# designs after: []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\PHYS-A~1\AppData\Local\Temp/ipykernel_16192/1903455614.py in <module>
#       9     new_atom_position, dist_destination = RL_operation(env, agent, atom_chosen, next_destination_nm, anchor_chosen, offset_nm, len_nm, i)
#      10     succeed = dist_destination<env.precision_lim
# ---> 11     atom_chosen, design_chosen, next_destination_nm, path, anchor_chosen, offset_nm, len_nm, done = env.step_large(succeed, new_atom_position)
#      12     if succeed:
#      13         print('design:',env.design_chosen,'destination:',env.next_destinatio_nm)
#
# ~\Documents\GitHub\Atom_manipulation_with_RL_new\Environment\Builder_Env.py in step_large(self, succeed, new_atom_position)
#     132             done = self.update_after_success(new_atom_position)
#     133         for i in range(self.atoms.shape[0]):
# --> 134             self.atom_chosen, self.design_chosen, self.obstacle_list = self.match_atoms_designs(i)
#     135             self.anchor_chosen = get_anchor(self.atom_chosen, np.vstack(self.anchors))
#     136             self.next_destinatio_nm, self.paths = self.find_path()
#
# ~\Documents\GitHub\Atom_manipulation_with_RL_new\Environment\Builder_Env.py in match_atoms_designs(self, i)
#     173     def match_atoms_designs(self, i = 0):
#     174         atoms, designs, costs, _, _, _ = assignment(self.atoms, self.designs)
# --> 175         j = np.flip(np.argsort(costs))[i]
#     176
#     177         atom_chosen = atoms[j,:]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
np.linalg.norm(env.next_destinatio_nm - env.design_chosen)
# Out:
# 0.0

# %%
from Environment.get_atom_coordinate import blob_detection

# %%
env.all_atom_absolute_nm_f.shape
# Out:
# (8, 2)

# %%
f, s = blob_detection(env.large_img_info['img_backward'])
print(s)
plt.imshow(env.large_img_info['img_backward'])
plt.scatter(f[:,0], f[:,1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\PHYS-A~1\AppData\Local\Temp/ipykernel_16192/1910349387.py in <module>
# ----> 1 f, s = blob_detection(env.large_img_info['img_backward'])
#       2 print(s)
#       3 plt.imshow(env.large_img_info['img_backward'])
#       4 plt.scatter(f[:,0], f[:,1])
#
# AttributeError: 'Structure_Builder' object has no attribute 'large_img_info'

# %%
f.shape
# Out:
# (8, 2)

# %%
env.all_atom_absolute_nm_f.shape
# Out:
# (8, 2)

# %%
env.all_atom_absolute_nm_b.shape
# Out:
# (9, 2)

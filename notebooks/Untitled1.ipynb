# %%
from Environment.createc_control import Createc_Controller
import numpy as np
from Environment.atom_drop import AtomDrop
from matplotlib import pyplot as plt

# %%
atomdrop = AtomDrop(pixel=64, scan_mV = 1000)
# Out:
# succeed to connect

# %%
atomdrop.find_min_Z(5.3, 0.02, -89, -82)
# Out:
# The scan will take 2.9 seconds
# Z approach: 5.3
# The scan will take 2.9 seconds
# Z approach: 5.319999999999999
# The scan will take 2.9 seconds
# Z approach: 5.339999999999999
# The scan will take 2.9 seconds
# Z approach: 5.3599999999999985
# The scan will take 2.9 seconds
# Z approach: 5.379999999999998
# The scan will take 2.9 seconds
# Z approach: 5.399999999999998
# The scan will take 2.9 seconds
# Z approach: 5.419999999999997
# The scan will take 2.9 seconds
# Z approach: 5.439999999999997
# The scan will take 2.9 seconds
# Z approach: 5.459999999999996
# The scan will take 2.9 seconds
# Z approach: 5.479999999999996
# The scan will take 2.9 seconds
# Z approach: 5.499999999999996
# The scan will take 2.9 seconds
# Z approach: 5.519999999999995
# The scan will take 2.9 seconds
# Z approach: 5.539999999999995
# The scan will take 2.9 seconds
# Z approach: 5.559999999999994
# The scan will take 2.9 seconds
# Z approach: 5.579999999999994
# The scan will take 2.9 seconds
# ...

# %%
createc_controller.stm.btn_tipform(128,128)

# %%
atomdrop.all_atom_absolute_nm_f
# Out:
# array([], dtype=float64)

# %%
img_info = atomdrop.large_img_info
img = img_info['img_forward']
offset_nm = img_info['offset_nm']
len_nm = img_info['len_nm']
extent = (offset_nm[0]-0.5*len_nm[0], offset_nm[0]+0.5*len_nm[0], offset_nm[1]+len_nm[0], offset_nm[1])
plt.imshow(img, extent = extent)
plt.scatter(atomdrop.all_atom_absolute_nm_f[:,0], atomdrop.all_atom_absolute_nm_f[:,1])

# %%
import importlib
import Environment.get_atom_coordinate
importlib.reload(Environment.get_atom_coordinate)
from Environment.get_atom_coordinate import blob_detection

# %%
blob_detection(img)
# Out:
# (array([], dtype=float64), array([], dtype=float64))
